# %%
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
df = gpd.read_file("GIS_18000_24925_01.shp") 
df.head()
# Out:
#     id                                           geometry
# 0  2.0  POLYGON ((-98.70293 18.77626, -98.70295 18.776...
# 1  2.0  POLYGON ((-98.49426 19.11224, -98.49162 19.115...
# 2  3.0  POLYGON ((-98.70885 18.78904, -98.71023 18.793...
# 3  4.0  POLYGON ((-98.69503 18.81032, -98.69686 18.814...
# 4  5.0  POLYGON ((-98.69792 18.97198, -98.69845 18.973...

# %%
plt.style.use('dark_background')
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(figsize=(50, 50))
 
# Control del título y los ejes
ax.set_title('Test running 1', 
             pad = 20, 
             fontdict={'fontsize':20, })
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
 
# Mostrar el mapa finalizado
df.plot(cmap='plasma', ax=ax, zorder=5)
# Out:
# <AxesSubplot:title={'center':'Test running 1'}, xlabel='Longitud', ylabel='Latitud'>
