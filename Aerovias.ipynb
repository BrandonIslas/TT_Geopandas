# %%
import pandas as pd
from shapely.geometry import Point, LineString, shape, MultiLineString
import geopandas as gpd
import matplotlib.pyplot as plt
from geopandas import GeoDataFrame
from shapely import ops
import numpy as np
import mplleaflet as mpl

# %%
df = pd.read_excel("AeroviasS.xls")
df.head()
# Out:
#      Latitud    Longitud  Nombre Aerovia
# 0  32.782222 -117.225556  VORTAC      J1
# 1  32.540556 -116.808056     VOR      J1
# 2  32.230278 -116.808056    FIJO      J1
# 3  30.545278 -115.955556     VOR      J1
# 4  28.026944 -114.022222     NDB      J1

# %%
multiLineList = []
multiLineName = []

# %%
condicionJ1= df[df["Aerovia"]=='J1']
condicionJ13= df[df["Aerovia"]=='J13']
condicionJ21= df[df["Aerovia"]=='J21']
condicionJ22= df[df["Aerovia"]=='J22']
condicionJ25= df[df["Aerovia"]=='J25']
condicionJ26= df[df["Aerovia"]=='J26']
condicionJ29= df[df["Aerovia"]=='J29']
condicionJ42= df[df["Aerovia"]=='J42']
condicionJ92= df[df["Aerovia"]=='J92']
condicionJ93= df[df["Aerovia"]=='J93']
condicionJ141= df[df["Aerovia"]=='J141']
condicionJ177= df[df["Aerovia"]=='J177']

# %%
geometry = [Point(xy) for xy in zip(condicionJ1.Longitud, condicionJ1.Latitud)]
condicion_J1 = GeoDataFrame(condicionJ1, geometry=geometry)
# Aggregate these points with the GroupBy
condicion_J1 = condicion_J1.groupby(['Aerovia'])['geometry'].apply(lambda x: LineString(x.tolist())if x.size > 1 else x.tolist())
condicion_J1 = GeoDataFrame(condicionJ1, geometry='geometry')
J1=LineString(condicion_J1.geometry)
multiLineList.append(J1)
multiLineName.append('J1')
J1

# %%
geometry = [Point(xy) for xy in zip(condicionJ13.Longitud, condicionJ13.Latitud)]
condicion_J13 = GeoDataFrame(condicionJ13, geometry=geometry)
J13 = LineString(condicion_J13['geometry'].tolist())
multiLineList.append(J13)
multiLineName.append('J13')
J13

# %%
geometry = [Point(xy) for xy in zip(condicionJ21.Longitud, condicionJ21.Latitud)]
condicion_J21 = GeoDataFrame(condicionJ21, geometry=geometry)
J21 = LineString(condicion_J21['geometry'].tolist())
multiLineList.append(J21)
multiLineName.append('J21')
J21

# %%
geometry = [Point(xy) for xy in zip(condicionJ22.Longitud, condicionJ22.Latitud)]
condicion_J22 = GeoDataFrame(condicionJ22, geometry=geometry)
J22 = LineString(condicion_J22['geometry'].tolist())
multiLineList.append(J22)
multiLineName.append('J22')
J22

# %%
geometry = [Point(xy) for xy in zip(condicionJ25.Longitud, condicionJ25.Latitud)]
condicion_J25 = GeoDataFrame(condicionJ25, geometry=geometry)
J25 = LineString(condicion_J25['geometry'].tolist())
multiLineList.append(J25)
multiLineName.append('J25')
J25

# %%
geometry = [Point(xy) for xy in zip(condicionJ26.Longitud, condicionJ26.Latitud)]
condicion_J26 = GeoDataFrame(condicionJ26, geometry=geometry)
J26 = LineString(condicion_J26['geometry'].tolist())
multiLineList.append(J26)
multiLineName.append('J26')
J26

# %%
geometry = [Point(xy) for xy in zip(condicionJ29.Longitud, condicionJ29.Latitud)]
condicion_J29 = GeoDataFrame(condicionJ29, geometry=geometry)
J29 = LineString(condicion_J29['geometry'].tolist())
multiLineList.append(J29)
multiLineName.append('J29')
J29

# %%
geometry = [Point(xy) for xy in zip(condicionJ42.Longitud, condicionJ42.Latitud)]
condicion_J42 = GeoDataFrame(condicionJ42, geometry=geometry)
J42 = LineString(condicion_J42['geometry'].tolist())
multiLineList.append(J42)
multiLineName.append('J42')
J42

# %%
geometry = [Point(xy) for xy in zip(condicionJ92.Longitud, condicionJ92.Latitud)]
condicion_J92 = GeoDataFrame(condicionJ92, geometry=geometry)
J92 = LineString(condicion_J92['geometry'].tolist())
multiLineList.append(J92)
multiLineName.append('J92')
J92

# %%
geometry = [Point(xy) for xy in zip(condicionJ93.Longitud, condicionJ93.Latitud)]
condicion_J93 = GeoDataFrame(condicionJ93, geometry=geometry)
J93 = LineString(condicion_J93['geometry'].tolist())
multiLineList.append(J93)
multiLineName.append('J93')
J93

# %%
geometry = [Point(xy) for xy in zip(condicionJ141.Longitud, condicionJ141.Latitud)]
condicion_J141 = GeoDataFrame(condicionJ141, geometry=geometry)
J141 = LineString(condicion_J141['geometry'].tolist())
multiLineList.append(J141)
multiLineName.append('J141')
J141

# %%
geometry = [Point(xy) for xy in zip(condicionJ177.Longitud, condicionJ177.Latitud)]
condicion_J177 = GeoDataFrame(condicionJ177, geometry=geometry)
J177 = LineString(condicion_J177['geometry'].tolist())
multiLineList.append(J177)
multiLineName.append('J177')
J177

# %%
condicionUA317= df[df["Aerovia"]=='UA317']
condicionUA552= df[df["Aerovia"]=='UA552']
condicionUA758= df[df["Aerovia"]=='UA758']
condicionUA766= df[df["Aerovia"]=='UA766']
condicionUA770= df[df["Aerovia"]=='UA770']

# %%
geometry = [Point(xy) for xy in zip(condicionUA317.Longitud, condicionUA317.Latitud)]
condicion_UA317 = GeoDataFrame(condicionUA317, geometry=geometry)
UA317 = LineString(condicion_UA317['geometry'].tolist())
multiLineList.append(UA317)
multiLineName.append('UA317')
UA317

# %%
geometry = [Point(xy) for xy in zip(condicionUA552.Longitud, condicionUA552.Latitud)]
condicion_UA552 = GeoDataFrame(condicionUA552, geometry=geometry)
UA552 = LineString(condicion_UA552['geometry'].tolist())
multiLineList.append(UA552)
multiLineName.append('UA552')
UA552

# %%
geometry = [Point(xy) for xy in zip(condicionUA758.Longitud, condicionUA758.Latitud)]
condicion_UA758 = GeoDataFrame(condicionUA758, geometry=geometry)
UA758 = LineString(condicion_UA758['geometry'].tolist())
multiLineList.append(UA758)
multiLineName.append('UA758')
UA758

# %%
geometry = [Point(xy) for xy in zip(condicionUA766.Longitud, condicionUA766.Latitud)]
condicion_UA766 = GeoDataFrame(condicionUA766, geometry=geometry)
UA766 = LineString(condicion_UA766['geometry'].tolist())
multiLineList.append(UA766)
multiLineName.append('UA766')
UA766

# %%
geometry = [Point(xy) for xy in zip(condicionUA770.Longitud, condicionUA770.Latitud)]
condicion_UA770 = GeoDataFrame(condicionUA770, geometry=geometry)
UA770 = LineString(condicion_UA770['geometry'].tolist())
multiLineList.append(UA770)
multiLineName.append('UA770')
UA770

# %%
condicionUB646= df[df["Aerovia"]=='UB646']
condicionUB753= df[df["Aerovia"]=='UB753']
condicionUB764= df[df["Aerovia"]=='UB764']
condicionUB879= df[df["Aerovia"]=='UB879']
condicionUB881= df[df["Aerovia"]=='UB881']

# %%
geometry = [Point(xy) for xy in zip(condicionUB646.Longitud, condicionUB646.Latitud)]
condicion_UB646 = GeoDataFrame(condicionUB646, geometry=geometry)
UB646 = LineString(condicion_UB646['geometry'].tolist())
multiLineList.append(UB646)
multiLineName.append('UB646')
UB646

# %%
geometry = [Point(xy) for xy in zip(condicionUB753.Longitud, condicionUB753.Latitud)]
condicion_UB753 = GeoDataFrame(condicionUB753, geometry=geometry)
UB753 = LineString(condicion_UB753['geometry'].tolist())
multiLineList.append(UB753)
multiLineName.append('UB753')
UB753

# %%
geometry = [Point(xy) for xy in zip(condicionUB764.Longitud, condicionUB764.Latitud)]
condicion_UB764 = GeoDataFrame(condicionUB764, geometry=geometry)
UB764 = LineString(condicion_UB764['geometry'].tolist())
multiLineList.append(UB764)
multiLineName.append('UB764')
UB764

# %%
geometry = [Point(xy) for xy in zip(condicionUB879.Longitud, condicionUB879.Latitud)]
condicion_UB879 = GeoDataFrame(condicionUB879, geometry=geometry)
UB879 = LineString(condicion_UB879['geometry'].tolist())
multiLineList.append(UB879)
multiLineName.append('UB879')
UB879

# %%
geometry = [Point(xy) for xy in zip(condicionUB881.Longitud, condicionUB881.Latitud)]
condicion_UB881 = GeoDataFrame(condicionUB881, geometry=geometry)
UB881 = LineString(condicion_UB881['geometry'].tolist())
multiLineList.append(UB881)
multiLineName.append('UB881')
UB881

# %%
condicionUG521= df[df["Aerovia"]=='UG521']
condicionUG633= df[df["Aerovia"]=='UG633']
condicionUG757= df[df["Aerovia"]=='UG757']
condicionUG765= df[df["Aerovia"]=='UG765']

# %%
geometry = [Point(xy) for xy in zip(condicionUG521.Longitud, condicionUG521.Latitud)]
condicion_UG521 = GeoDataFrame(condicionUG521, geometry=geometry)
UG521 = LineString(condicion_UG521['geometry'].tolist())
multiLineList.append(UG521)
multiLineName.append('UG521')
UG521

# %%
geometry = [Point(xy) for xy in zip(condicionUG633.Longitud, condicionUG633.Latitud)]
condicion_UG633 = GeoDataFrame(condicionUG633, geometry=geometry)
UG633 = LineString(condicion_UG633['geometry'].tolist())
multiLineList.append(UG633)
multiLineName.append('UG633')
UG633

# %%
geometry = [Point(xy) for xy in zip(condicionUG757.Longitud, condicionUG757.Latitud)]
condicion_UG757 = GeoDataFrame(condicionUG757, geometry=geometry)
UG757 = LineString(condicion_UG757['geometry'].tolist())
multiLineList.append(UG757)
multiLineName.append('UG757')
UG757

# %%
geometry = [Point(xy) for xy in zip(condicionUG765.Longitud, condicionUG765.Latitud)]
condicion_UG765 = GeoDataFrame(condicionUG765, geometry=geometry)
UG765 = LineString(condicion_UG765['geometry'].tolist())
multiLineList.append(UG765)
multiLineName.append('UG765')
UG765

# %%
condicionUJ1_E= df[df["Aerovia"]=='UJ1 E']

# %%
geometry = [Point(xy) for xy in zip(condicionUJ1_E.Longitud, condicionUJ1_E.Latitud)]
condicion_UJ1_E = GeoDataFrame(condicionUJ1_E, geometry=geometry)
UJ1_E = LineString(condicion_UJ1_E['geometry'].tolist())
multiLineList.append(UJ1_E)
multiLineName.append('UJ1_E')
UJ1_E

# %%
condicionUJ2= df[df["Aerovia"]=='UJ2']
condicionUJ3= df[df["Aerovia"]=='UJ3']
condicionUJ4= df[df["Aerovia"]=='UJ4']
condicionUJ5= df[df["Aerovia"]=='UJ5']
condicionUJ6= df[df["Aerovia"]=='UJ6']
condicionUJ7= df[df["Aerovia"]=='UJ7']
condicionUJ8= df[df["Aerovia"]=='UJ8']
condicionUJ9= df[df["Aerovia"]=='UJ9']
condicionUJ10= df[df["Aerovia"]=='UJ10']
condicionUJ11= df[df["Aerovia"]=='UJ11']
condicionUJ11_E= df[df["Aerovia"]=='UJ11 E']
condicionUJ12= df[df["Aerovia"]=='UJ12']
condicionUJ13= df[df["Aerovia"]=='UJ13']
condicionUJ14= df[df["Aerovia"]=='UJ14']
condicionUJ14_N= df[df["Aerovia"]=='UJ14 N']
condicionUJ14_S= df[df["Aerovia"]=='UJ14 S']
condicionUJ15= df[df["Aerovia"]=='UJ15']
condicionUJ15_E= df[df["Aerovia"]=='UJ15 E']
condicionUJ16= df[df["Aerovia"]=='UJ16']
condicionUJ17= df[df["Aerovia"]=='UJ17']
condicionUJ18= df[df["Aerovia"]=='UJ18']
condicionUJ19= df[df["Aerovia"]=='UJ19']
condicionUJ20= df[df["Aerovia"]=='UJ20']
condicionUJ21_E= df[df["Aerovia"]=='UJ21 E']
condicionUJ21_W= df[df["Aerovia"]=='UJ21 W']
condicionUJ23= df[df["Aerovia"]=='UJ23']
condicionUJ24= df[df["Aerovia"]=='UJ24']
condicionUJ24_S= df[df["Aerovia"]=='UJ24 S']
condicionUJ25= df[df["Aerovia"]=='UJ25']
condicionUJ26= df[df["Aerovia"]=='UJ26']
condicionUJ27= df[df["Aerovia"]=='UJ27']
condicionUJ28= df[df["Aerovia"]=='UJ28']
condicionUJ30= df[df["Aerovia"]=='UJ30']
condicionUJ31= df[df["Aerovia"]=='UJ31']
condicionUJ32= df[df["Aerovia"]=='UJ32']
condicionUJ33= df[df["Aerovia"]=='UJ33']
condicionUJ34= df[df["Aerovia"]=='UJ34']
condicionUJ35= df[df["Aerovia"]=='UJ35']
condicionUJ36= df[df["Aerovia"]=='UJ36']
condicionUJ37= df[df["Aerovia"]=='UJ37']
condicionUJ38= df[df["Aerovia"]=='UJ38']
condicionUJ39= df[df["Aerovia"]=='UJ39']
condicionUJ40= df[df["Aerovia"]=='UJ40']
condicionUJ41= df[df["Aerovia"]=='UJ41']
condicionUJ45= df[df["Aerovia"]=='UJ45']
condicionUJ46= df[df["Aerovia"]=='UJ46']
condicionUJ47= df[df["Aerovia"]=='UJ47']
condicionUJ48= df[df["Aerovia"]=='UJ48']
condicionUJ50= df[df["Aerovia"]=='UJ50']
condicionUJ51= df[df["Aerovia"]=='UJ51']

# %%
geometry = [Point(xy) for xy in zip(condicionUJ2.Longitud, condicionUJ2.Latitud)]
condicion_UJ2 = GeoDataFrame(condicionUJ2, geometry=geometry)
UJ2 = LineString(condicion_UJ2['geometry'].tolist())
multiLineList.append(UJ2)
multiLineName.append('UJ2')

geometry = [Point(xy) for xy in zip(condicionUJ3.Longitud, condicionUJ3.Latitud)]
condicion_UJ3 = GeoDataFrame(condicionUJ3, geometry=geometry)
UJ3 = LineString(condicion_UJ3['geometry'].tolist())
multiLineList.append(UJ3)
multiLineName.append('UJ3')

geometry = [Point(xy) for xy in zip(condicionUJ4.Longitud, condicionUJ4.Latitud)]
condicion_UJ4 = GeoDataFrame(condicionUJ4, geometry=geometry)
UJ4 = LineString(condicion_UJ4['geometry'].tolist())
multiLineList.append(UJ4)
multiLineName.append('UJ4')

geometry = [Point(xy) for xy in zip(condicionUJ5.Longitud, condicionUJ5.Latitud)]
condicion_UJ5 = GeoDataFrame(condicionUJ5, geometry=geometry)
UJ5 = LineString(condicion_UJ5['geometry'].tolist())
multiLineList.append(UJ5)
multiLineName.append('UJ5')

geometry = [Point(xy) for xy in zip(condicionUJ6.Longitud, condicionUJ6.Latitud)]
condicion_UJ6 = GeoDataFrame(condicionUJ6, geometry=geometry)
UJ6 = LineString(condicion_UJ6['geometry'].tolist())
multiLineList.append(UJ6)
multiLineName.append('UJ6')

geometry = [Point(xy) for xy in zip(condicionUJ7.Longitud, condicionUJ7.Latitud)]
condicion_UJ7 = GeoDataFrame(condicionUJ7, geometry=geometry)
UJ7 = LineString(condicion_UJ7['geometry'].tolist())
multiLineList.append(UJ7)
multiLineName.append('UJ7')

geometry = [Point(xy) for xy in zip(condicionUJ8.Longitud, condicionUJ8.Latitud)]
condicion_UJ8 = GeoDataFrame(condicionUJ8, geometry=geometry)
UJ8 = LineString(condicion_UJ8['geometry'].tolist())
multiLineList.append(UJ8)
multiLineName.append('UJ8')

geometry = [Point(xy) for xy in zip(condicionUJ9.Longitud, condicionUJ9.Latitud)]
condicion_UJ9 = GeoDataFrame(condicionUJ9, geometry=geometry)
UJ9 = LineString(condicion_UJ9['geometry'].tolist())
multiLineList.append(UJ9)
multiLineName.append('UJ9')

geometry = [Point(xy) for xy in zip(condicionUJ10.Longitud, condicionUJ10.Latitud)]
condicion_UJ10 = GeoDataFrame(condicionUJ10, geometry=geometry)
UJ10 = LineString(condicion_UJ10['geometry'].tolist())
multiLineList.append(UJ10)
multiLineName.append('UJ10')

geometry = [Point(xy) for xy in zip(condicionUJ11.Longitud, condicionUJ11.Latitud)]
condicion_UJ11 = GeoDataFrame(condicionUJ11, geometry=geometry)
UJ11 = LineString(condicion_UJ11['geometry'].tolist())
multiLineList.append(UJ11)
multiLineName.append('UJ11')

# %%
geometry = [Point(xy) for xy in zip(condicionUJ11_E.Longitud, condicionUJ11_E.Latitud)]
condicion_UJ11_E = GeoDataFrame(condicionUJ11_E, geometry=geometry)
UJ11_E = LineString(condicion_UJ11_E['geometry'].tolist())
multiLineList.append(UJ11_E)
multiLineName.append('UJ11_E')

geometry = [Point(xy) for xy in zip(condicionUJ12.Longitud, condicionUJ12.Latitud)]
condicion_UJ12 = GeoDataFrame(condicionUJ12, geometry=geometry)
UJ12 = LineString(condicion_UJ12['geometry'].tolist())
multiLineList.append(UJ12)
multiLineName.append('UJ12')

geometry = [Point(xy) for xy in zip(condicionUJ13.Longitud, condicionUJ13.Latitud)]
condicion_UJ13 = GeoDataFrame(condicionUJ13, geometry=geometry)
UJ13 = LineString(condicion_UJ13['geometry'].tolist())
multiLineList.append(UJ13)
multiLineName.append('UJ13')

geometry = [Point(xy) for xy in zip(condicionUJ14.Longitud, condicionUJ14.Latitud)]
condicion_UJ14 = GeoDataFrame(condicionUJ14, geometry=geometry)
UJ14 = LineString(condicion_UJ14['geometry'].tolist())
multiLineList.append(UJ14)
multiLineName.append('UJ14')

geometry = [Point(xy) for xy in zip(condicionUJ14_N.Longitud, condicionUJ14_N.Latitud)]
condicion_UJ14_N = GeoDataFrame(condicionUJ14_N, geometry=geometry)
UJ14_N = LineString(condicion_UJ14_N['geometry'].tolist())
multiLineList.append(UJ14_N)
multiLineName.append('UJ14_N')

geometry = [Point(xy) for xy in zip(condicionUJ14_S.Longitud, condicionUJ14_S.Latitud)]
condicion_UJ14_S = GeoDataFrame(condicionUJ14_S, geometry=geometry)
UJ14_S = LineString(condicion_UJ14_S['geometry'].tolist())
multiLineList.append(UJ14_S)
multiLineName.append('UJ14_S')

geometry = [Point(xy) for xy in zip(condicionUJ15.Longitud, condicionUJ15.Latitud)]
condicion_UJ15 = GeoDataFrame(condicionUJ15, geometry=geometry)
UJ15 = LineString(condicion_UJ15['geometry'].tolist())
multiLineList.append(UJ15)
multiLineName.append('UJ15')

geometry = [Point(xy) for xy in zip(condicionUJ15_E.Longitud, condicionUJ15_E.Latitud)]
condicion_UJ15_E = GeoDataFrame(condicionUJ15_E, geometry=geometry)
UJ15_E = LineString(condicion_UJ15_E['geometry'].tolist())
multiLineList.append(UJ15_E)
multiLineName.append('UJ15_E')

geometry = [Point(xy) for xy in zip(condicionUJ16.Longitud, condicionUJ16.Latitud)]
condicion_UJ16 = GeoDataFrame(condicionUJ16, geometry=geometry)
UJ16 = LineString(condicion_UJ16['geometry'].tolist())
multiLineList.append(UJ16)
multiLineName.append('UJ16')

geometry = [Point(xy) for xy in zip(condicionUJ17.Longitud, condicionUJ17.Latitud)]
condicion_UJ17 = GeoDataFrame(condicionUJ17, geometry=geometry)
UJ17 = LineString(condicion_UJ17['geometry'].tolist())
multiLineList.append(UJ17)
multiLineName.append('UJ17')

# %%
geometry = [Point(xy) for xy in zip(condicionUJ18.Longitud, condicionUJ18.Latitud)]
condicion_UJ18 = GeoDataFrame(condicionUJ18, geometry=geometry)
UJ18 = LineString(condicion_UJ18['geometry'].tolist())
multiLineList.append(UJ17)
multiLineName.append('UJ17')

geometry = [Point(xy) for xy in zip(condicionUJ19.Longitud, condicionUJ19.Latitud)]
condicion_UJ19 = GeoDataFrame(condicionUJ19, geometry=geometry)
UJ19 = LineString(condicion_UJ19['geometry'].tolist())
multiLineList.append(UJ19)
multiLineName.append('UJ19')

geometry = [Point(xy) for xy in zip(condicionUJ20.Longitud, condicionUJ20.Latitud)]
condicion_UJ20 = GeoDataFrame(condicionUJ20, geometry=geometry)
UJ20 = LineString(condicion_UJ20['geometry'].tolist())
multiLineList.append(UJ20)
multiLineName.append('UJ20')

geometry = [Point(xy) for xy in zip(condicionUJ21_E.Longitud, condicionUJ21_E.Latitud)]
condicion_UJ21_E = GeoDataFrame(condicionUJ21_E, geometry=geometry)
UJ21_E = LineString(condicion_UJ21_E['geometry'].tolist())
multiLineList.append(UJ21_E)
multiLineName.append('UJ21_E')

geometry = [Point(xy) for xy in zip(condicionUJ21_W.Longitud, condicionUJ21_W.Latitud)]
condicion_UJ21_W = GeoDataFrame(condicionUJ21_W, geometry=geometry)
UJ21_W = LineString(condicion_UJ21_W['geometry'].tolist())
multiLineList.append(UJ21_W)
multiLineName.append('UJ21_W')

geometry = [Point(xy) for xy in zip(condicionUJ23.Longitud, condicionUJ23.Latitud)]
condicion_UJ23 = GeoDataFrame(condicionUJ23, geometry=geometry)
UJ23 = LineString(condicion_UJ23['geometry'].tolist())
multiLineList.append(UJ23)
multiLineName.append('UJ23')

geometry = [Point(xy) for xy in zip(condicionUJ24.Longitud, condicionUJ24.Latitud)]
condicion_UJ24 = GeoDataFrame(condicionUJ24, geometry=geometry)
UJ24 = LineString(condicion_UJ24['geometry'].tolist())
multiLineList.append(UJ24)
multiLineName.append('UJ24')

geometry = [Point(xy) for xy in zip(condicionUJ24_S.Longitud, condicionUJ24_S.Latitud)]
condicion_UJ24_S = GeoDataFrame(condicionUJ24_S, geometry=geometry)
UJ24_S = LineString(condicion_UJ24_S['geometry'].tolist())
multiLineList.append(UJ24_S)
multiLineName.append('UJ24_S')

geometry = [Point(xy) for xy in zip(condicionUJ25.Longitud, condicionUJ25.Latitud)]
condicion_UJ25 = GeoDataFrame(condicionUJ25, geometry=geometry)
UJ25 = LineString(condicion_UJ25['geometry'].tolist())
multiLineList.append(UJ25)
multiLineName.append('UJ25')

geometry = [Point(xy) for xy in zip(condicionUJ26.Longitud, condicionUJ26.Latitud)]
condicion_UJ26 = GeoDataFrame(condicionUJ26, geometry=geometry)
UJ26 = LineString(condicion_UJ26['geometry'].tolist())
multiLineList.append(UJ26)
multiLineName.append('UJ26')

# %%
geometry = [Point(xy) for xy in zip(condicionUJ27.Longitud, condicionUJ27.Latitud)]
condicion_UJ27 = GeoDataFrame(condicionUJ27, geometry=geometry)
UJ27 = LineString(condicion_UJ27['geometry'].tolist())
multiLineList.append(UJ27)
multiLineName.append('UJ27')

geometry = [Point(xy) for xy in zip(condicionUJ28.Longitud, condicionUJ28.Latitud)]
condicion_UJ28 = GeoDataFrame(condicionUJ28, geometry=geometry)
UJ28 = LineString(condicion_UJ28['geometry'].tolist())
multiLineList.append(UJ28)
multiLineName.append('UJ28')

geometry = [Point(xy) for xy in zip(condicionUJ30.Longitud, condicionUJ30.Latitud)]
condicion_UJ30 = GeoDataFrame(condicionUJ30, geometry=geometry)
UJ30 = LineString(condicion_UJ30['geometry'].tolist())
multiLineList.append(UJ30)
multiLineName.append('UJ30')

geometry = [Point(xy) for xy in zip(condicionUJ31.Longitud, condicionUJ31.Latitud)]
condicion_UJ31 = GeoDataFrame(condicionUJ31, geometry=geometry)
UJ31 = LineString(condicion_UJ31['geometry'].tolist())
multiLineList.append(UJ31)
multiLineName.append('UJ31')

geometry = [Point(xy) for xy in zip(condicionUJ32.Longitud, condicionUJ32.Latitud)]
condicion_UJ32 = GeoDataFrame(condicionUJ32, geometry=geometry)
UJ32 = LineString(condicion_UJ32['geometry'].tolist())
multiLineList.append(UJ32)
multiLineName.append('UJ32')

geometry = [Point(xy) for xy in zip(condicionUJ33.Longitud, condicionUJ33.Latitud)]
condicion_UJ33 = GeoDataFrame(condicionUJ33, geometry=geometry)
UJ33 = LineString(condicion_UJ33['geometry'].tolist())
multiLineList.append(UJ33)
multiLineName.append('UJ33')

geometry = [Point(xy) for xy in zip(condicionUJ34.Longitud, condicionUJ34.Latitud)]
condicion_UJ34 = GeoDataFrame(condicionUJ34, geometry=geometry)
UJ34 = LineString(condicion_UJ34['geometry'].tolist())
multiLineList.append(UJ34)
multiLineName.append('UJ34')

geometry = [Point(xy) for xy in zip(condicionUJ35.Longitud, condicionUJ35.Latitud)]
condicion_UJ35 = GeoDataFrame(condicionUJ35, geometry=geometry)
UJ35 = LineString(condicion_UJ35['geometry'].tolist())
multiLineList.append(UJ35)
multiLineName.append('UJ35')

geometry = [Point(xy) for xy in zip(condicionUJ36.Longitud, condicionUJ36.Latitud)]
condicion_UJ36 = GeoDataFrame(condicionUJ36, geometry=geometry)
UJ36 = LineString(condicion_UJ36['geometry'].tolist())
multiLineList.append(UJ36)
multiLineName.append('UJ36')

geometry = [Point(xy) for xy in zip(condicionUJ37.Longitud, condicionUJ37.Latitud)]
condicion_UJ37 = GeoDataFrame(condicionUJ37, geometry=geometry)
UJ37 = LineString(condicion_UJ37['geometry'].tolist())
multiLineList.append(UJ37)
multiLineName.append('UJ37')

# %%
geometry = [Point(xy) for xy in zip(condicionUJ38.Longitud, condicionUJ38.Latitud)]
condicion_UJ38 = GeoDataFrame(condicionUJ38, geometry=geometry)
UJ38 = LineString(condicion_UJ38['geometry'].tolist())
multiLineList.append(UJ38)
multiLineName.append('UJ38')

geometry = [Point(xy) for xy in zip(condicionUJ39.Longitud, condicionUJ39.Latitud)]
condicion_UJ39 = GeoDataFrame(condicionUJ39, geometry=geometry)
UJ39 = LineString(condicion_UJ39['geometry'].tolist())
multiLineList.append(UJ39)
multiLineName.append('UJ39')

geometry = [Point(xy) for xy in zip(condicionUJ40.Longitud, condicionUJ40.Latitud)]
condicion_UJ40 = GeoDataFrame(condicionUJ40, geometry=geometry)
UJ40 = LineString(condicion_UJ40['geometry'].tolist())
multiLineList.append(UJ40)
multiLineName.append('UJ40')

geometry = [Point(xy) for xy in zip(condicionUJ41.Longitud, condicionUJ41.Latitud)]
condicion_UJ41 = GeoDataFrame(condicionUJ41, geometry=geometry)
UJ41 = LineString(condicion_UJ41['geometry'].tolist())
multiLineList.append(UJ41)
multiLineName.append('UJ41')

geometry = [Point(xy) for xy in zip(condicionUJ45.Longitud, condicionUJ45.Latitud)]
condicion_UJ45 = GeoDataFrame(condicionUJ45, geometry=geometry)
UJ45 = LineString(condicion_UJ45['geometry'].tolist())
multiLineList.append(UJ45)
multiLineName.append('UJ45')

geometry = [Point(xy) for xy in zip(condicionUJ46.Longitud, condicionUJ46.Latitud)]
condicion_UJ46 = GeoDataFrame(condicionUJ46, geometry=geometry)
UJ46 = LineString(condicion_UJ46['geometry'].tolist())
multiLineList.append(UJ46)
multiLineName.append('UJ46')

geometry = [Point(xy) for xy in zip(condicionUJ47.Longitud, condicionUJ47.Latitud)]
condicion_UJ47 = GeoDataFrame(condicionUJ47, geometry=geometry)
UJ47 = LineString(condicion_UJ47['geometry'].tolist())
multiLineList.append(UJ47)
multiLineName.append('UJ47')

geometry = [Point(xy) for xy in zip(condicionUJ48.Longitud, condicionUJ48.Latitud)]
condicion_UJ48 = GeoDataFrame(condicionUJ48, geometry=geometry)
UJ48 = LineString(condicion_UJ48['geometry'].tolist())
multiLineList.append(UJ48)
multiLineName.append('UJ48')

geometry = [Point(xy) for xy in zip(condicionUJ50.Longitud, condicionUJ50.Latitud)]
condicion_UJ50 = GeoDataFrame(condicionUJ50, geometry=geometry)
UJ50 = LineString(condicion_UJ50['geometry'].tolist())
multiLineList.append(UJ50)
multiLineName.append('UJ50')

geometry = [Point(xy) for xy in zip(condicionUJ51.Longitud, condicionUJ51.Latitud)]
condicion_UJ51 = GeoDataFrame(condicionUJ51, geometry=geometry)
UJ51 = LineString(condicion_UJ51['geometry'].tolist())
multiLineList.append(UJ51)
multiLineName.append('UJ51')

# %%
condicionJU52= df[df["Aerovia"]=='JU52']
condicionJU53= df[df["Aerovia"]=='JU53']

# %%
geometry = [Point(xy) for xy in zip(condicionJU52.Longitud, condicionJU52.Latitud)]
condicion_JU52 = GeoDataFrame(condicionJU52, geometry=geometry)
JU52 = LineString(condicion_JU52['geometry'].tolist())
multiLineList.append(JU52)
multiLineName.append('JU52')

geometry = [Point(xy) for xy in zip(condicionJU53.Longitud, condicionJU53.Latitud)]
condicion_JU53 = GeoDataFrame(condicionJU53, geometry=geometry)
JU53 = LineString(condicion_JU53['geometry'].tolist())
multiLineList.append(JU53)
multiLineName.append('JU53')

# %%
condicionUJ54= df[df["Aerovia"]=='UJ54']
condicionUJ55= df[df["Aerovia"]=='UJ55']
condicionUJ61= df[df["Aerovia"]=='UJ61']
condicionUJ63= df[df["Aerovia"]=='UJ63']
condicionUJ64= df[df["Aerovia"]=='UJ64']
condicionUJ65= df[df["Aerovia"]=='UJ65']
condicionUJ69= df[df["Aerovia"]=='UJ69']
condicionUJ70= df[df["Aerovia"]=='UJ70']
condicionUJ71= df[df["Aerovia"]=='UJ71']
condicionUJ81= df[df["Aerovia"]=='UJ81']
condicionUJ84= df[df["Aerovia"]=='UJ84']
condicionUJ95= df[df["Aerovia"]=='UJ95']
condicionUJ102= df[df["Aerovia"]=='UJ102']

# %%
geometry = [Point(xy) for xy in zip(condicionUJ54.Longitud, condicionUJ54.Latitud)]
condicion_UJ54 = GeoDataFrame(condicionUJ54, geometry=geometry)
UJ54 = LineString(condicion_UJ54['geometry'].tolist())
multiLineList.append(UJ54)
multiLineName.append('UJ54')

geometry = [Point(xy) for xy in zip(condicionUJ55.Longitud, condicionUJ55.Latitud)]
condicion_UJ55 = GeoDataFrame(condicionUJ55, geometry=geometry)
UJ55 = LineString(condicion_UJ55['geometry'].tolist())
multiLineList.append(UJ55)
multiLineName.append('UJ55')

geometry = [Point(xy) for xy in zip(condicionUJ61.Longitud, condicionUJ61.Latitud)]
condicion_UJ61 = GeoDataFrame(condicionUJ61, geometry=geometry)
UJ61 = LineString(condicion_UJ61['geometry'].tolist())
multiLineList.append(UJ61)
multiLineName.append('UJ61')


geometry = [Point(xy) for xy in zip(condicionUJ63.Longitud, condicionUJ63.Latitud)]
condicion_UJ63 = GeoDataFrame(condicionUJ63, geometry=geometry)
UJ63 = LineString(condicion_UJ63['geometry'].tolist())
multiLineList.append(UJ63)
multiLineName.append('UJ63')


geometry = [Point(xy) for xy in zip(condicionUJ64.Longitud, condicionUJ64.Latitud)]
condicion_UJ64 = GeoDataFrame(condicionUJ64, geometry=geometry)
UJ64 = LineString(condicion_UJ64['geometry'].tolist())
multiLineList.append(UJ64)
multiLineName.append('UJ64')


geometry = [Point(xy) for xy in zip(condicionUJ65.Longitud, condicionUJ65.Latitud)]
condicion_UJ65 = GeoDataFrame(condicionUJ65, geometry=geometry)
UJ65 = LineString(condicion_UJ65['geometry'].tolist())
multiLineList.append(UJ65)
multiLineName.append('UJ65')


geometry = [Point(xy) for xy in zip(condicionUJ69.Longitud, condicionUJ69.Latitud)]
condicion_UJ69 = GeoDataFrame(condicionUJ69, geometry=geometry)
UJ69 = LineString(condicion_UJ69['geometry'].tolist())
multiLineList.append(UJ69)
multiLineName.append('UJ69')

geometry = [Point(xy) for xy in zip(condicionUJ70.Longitud, condicionUJ70.Latitud)]
condicion_UJ70 = GeoDataFrame(condicionUJ70, geometry=geometry)
UJ70 = LineString(condicion_UJ70['geometry'].tolist())
multiLineList.append(UJ70)
multiLineName.append('UJ70')

geometry = [Point(xy) for xy in zip(condicionUJ71.Longitud, condicionUJ71.Latitud)]
condicion_UJ71 = GeoDataFrame(condicionUJ71, geometry=geometry)
UJ71 = LineString(condicion_UJ71['geometry'].tolist())
multiLineList.append(UJ71)
multiLineName.append('UJ71')

geometry = [Point(xy) for xy in zip(condicionUJ81.Longitud, condicionUJ81.Latitud)]
condicion_UJ81 = GeoDataFrame(condicionUJ81, geometry=geometry)
UJ81 = LineString(condicion_UJ81['geometry'].tolist())
multiLineList.append(UJ81)
multiLineName.append('UJ81')

geometry = [Point(xy) for xy in zip(condicionUJ84.Longitud, condicionUJ84.Latitud)]
condicion_UJ84 = GeoDataFrame(condicionUJ84, geometry=geometry)
UJ84 = LineString(condicion_UJ84['geometry'].tolist())
multiLineList.append(UJ84)
multiLineName.append('UJ84')

geometry = [Point(xy) for xy in zip(condicionUJ95.Longitud, condicionUJ95.Latitud)]
condicion_UJ95 = GeoDataFrame(condicionUJ95, geometry=geometry)
UJ95 = LineString(condicion_UJ95['geometry'].tolist())
multiLineList.append(UJ95)
multiLineName.append('UJ95')

geometry = [Point(xy) for xy in zip(condicionUJ102.Longitud, condicionUJ102.Latitud)]
condicion_UJ102 = GeoDataFrame(condicionUJ102, geometry=geometry)
UJ102 = LineString(condicion_UJ102['geometry'].tolist())
multiLineList.append(UJ102)
multiLineName.append('UJ102')

# %%
condicionUR506= df[df["Aerovia"]=='UR506']
condicionUR519= df[df["Aerovia"]=='UR519']
condicionUR522= df[df["Aerovia"]=='UR522']
condicionUR640= df[df["Aerovia"]=='UR640']
condicionUR644= df[df["Aerovia"]=='UR644']
condicionUR899= df[df["Aerovia"]=='UR899']

# %%
geometry = [Point(xy) for xy in zip(condicionUR506.Longitud, condicionUR506.Latitud)]
condicion_UR506 = GeoDataFrame(condicionUR506, geometry=geometry)
UR506 = LineString(condicion_UR506['geometry'].tolist())
multiLineList.append(UR506)
multiLineName.append('UR506')

geometry = [Point(xy) for xy in zip(condicionUR519.Longitud, condicionUR519.Latitud)]
condicion_UR519 = GeoDataFrame(condicionUR519, geometry=geometry)
UR519 = LineString(condicion_UR519['geometry'].tolist())
multiLineList.append(UR519)
multiLineName.append('UR519')

geometry = [Point(xy) for xy in zip(condicionUR522.Longitud, condicionUR522.Latitud)]
condicion_UR522 = GeoDataFrame(condicionUR522, geometry=geometry)
UR522 = LineString(condicion_UR522['geometry'].tolist())
multiLineList.append(UR522)
multiLineName.append('UR522')

geometry = [Point(xy) for xy in zip(condicionUR640.Longitud, condicionUR640.Latitud)]
condicion_UR640 = GeoDataFrame(condicionUR640, geometry=geometry)
UR640 = LineString(condicion_UR640['geometry'].tolist())
multiLineList.append(UR640)
multiLineName.append('UR640')

geometry = [Point(xy) for xy in zip(condicionUR644.Longitud, condicionUR644.Latitud)]
condicion_UR644 = GeoDataFrame(condicionUR644, geometry=geometry)
UR644 = LineString(condicion_UR644['geometry'].tolist())
multiLineList.append(UR644)
multiLineName.append('UR644')

geometry = [Point(xy) for xy in zip(condicionUR899.Longitud, condicionUR899.Latitud)]
condicion_UR899 = GeoDataFrame(condicionUR899, geometry=geometry)
UR899 = LineString(condicion_UR899['geometry'].tolist())
multiLineList.append(UJ102)
multiLineName.append('UR899')

# %%
d = {'Name':multiLineName , 'geometry': multiLineList}
df = gpd.GeoDataFrame(d, crs="EPSG:4326") #(change epsg)
df.to_file('aerovias_mexico.shp')

# %%
aero = gpd.read_file("aerovias_mexico.shp")
aero.head()
# Out:
#   Name                                           geometry
# 0   J1  LINESTRING (-117.22556 32.78222, -116.80806 32...
# 1  J13  LINESTRING (-107.28056 33.28250, -106.71194 31...
# 2  J21  LINESTRING (-99.41778 27.47861, -99.28861 26.4...
# 3  J22  LINESTRING (-99.41778 27.47861, -99.56472 27.4...
# 4  J25  LINESTRING (-97.37528 25.92417, -97.52389 25.7...

# %%
plt.style.use('dark_background')
# Control del tamaño de la figura del mapa
fig, ax = plt.subplots(figsize=(80, 50))
 
# Control del título y los ejes
ax.set_title('Aerovias de la Republica Mèxicana', 
             pad = 20, 
             fontdict={'fontsize':20, })
ax.set_xlabel('Longitud')
ax.set_ylabel('Latitud')
 
# Mostrar el mapa finalizado
aero.plot(cmap='plasma', ax=ax, zorder=5)
# Out:
# <AxesSubplot:title={'center':'Aerovias de la Republica Mèxicana'}, xlabel='Longitud', ylabel='Latitud'>
